# %%
import numpy as np
from joblib import Parallel, delayed, parallel_backend
from itertools import product
import pandas as pd
import celer

from sklearn.model_selection import KFold

from libsvmdata import fetch_libsvm

from sparse_ho.models import Lasso, SparseLogreg
from sparse_ho.criterion import HeldOutMSE, HeldOutLogistic, CrossVal
from sparse_ho.utils import Monitor
from sparse_ho.optimizers import GradientDescent

from sparse_ho import ImplicitForward
from sparse_ho.grid_search import grid_search
from sparse_ho.ho import hyperopt_wrapper

from sparse_ho.ho import grad_search

model_name = "lasso"

dict_t_max = {}
dict_t_max["rcv1_train"] = 300
dict_t_max["real-sim"] = 100
dict_t_max["leukemia"] = 10
dict_t_max["news20"] = 10_000

#######################################################################
# dataset_names = ["rcv1_train"]
# uncomment the following line to launch the experiments on other
dataset_names = ["real-sim"]
methods = [
    "implicit_forward", "implicit_forward_approx", 'grid_search',
    'random', 'bayesian']
tolerance_decreases = ["constant"]
tol = 1e-8
n_outers = [75]

dict_n_outers = {}
dict_n_outers["news20", "implicit_forward"] = 50
dict_n_outers["news20", "forward"] = 60
dict_n_outers["news20", "implicit"] = 6
dict_n_outers["news20", "bayesian"] = 75
dict_n_outers["news20", "random"] = 35

dict_n_outers["finance", "implicit_forward"] = 125
dict_n_outers["finance", "forward"] = 75
dict_n_outers["finance", "implicit"] = 6
dict_n_outers["finance", "bayesian"] = 75
dict_n_outers["finance", "random"] = 50


#######################################################################
n_jobs = 1
#n_jobs = len(dataset_names) * len(methods) * len(tolerance_decreases)
#n_jobs = min(n_jobs, 10)
#######################################################################


def parallel_function(
        dataset_name, method, tol=1e-5, n_outer=50,
        tolerance_decrease='constant'):

    # load data
    X, y = fetch_libsvm(dataset_name)
    y -= y.mean()
    # compute alpha_max
    alpha_max = np.abs(X.T @ y).max() / len(y)

    if model_name == "logreg":
        alpha_max /= 2
    alpha_min = alpha_max / 10_000

    if model_name == "lasso":
        estimator = celer.Lasso(
            fit_intercept=False, max_iter=10, warm_start=True, tol=tol)
        model = Lasso(estimator=estimator)
    elif model_name == "logreg":
        model = SparseLogreg(estimator=estimator)

    # TODO improve this
    try:
        n_outer = dict_n_outers[dataset_name, method]
    except Exception:
        n_outer = 20

    size_loop = 1

    for _ in range(size_loop):
        if model_name == "lasso":
            sub_criterion = HeldOutMSE(None, None)
        elif model_name == "logreg":
            criterion = HeldOutLogistic(None, None)
        kf = KFold(n_splits=5, shuffle=True, random_state=42)
        criterion = CrossVal(sub_criterion, cv=kf)

        algo = ImplicitForward(tol_jac=1e-3)
        monitor = Monitor()
        t_max = dict_t_max[dataset_name]
        if method == 'grid_search':
            grid_search(criterion, model, X, y, alpha_min, alpha_max,
                monitor, max_evals=10, tol=tol)
        elif method == 'random' or method == 'bayesian':
            hyperopt_wrapper(
                algo, criterion, model, X, y, alpha_min, alpha_max,
                monitor, max_evals=3, tol=tol, method=method, size_space=1,
                t_max=t_max)
        elif method.startswith("implicit_forward"):
            # do gradient descent to find the optimal lambda
            alpha0 = alpha_max / 100
            n_outer = 1
            if method == 'implicit_forward':
                optimizer = GradientDescent(
                    n_outer=n_outer, p_grad_norm=1, verbose=True, tol=tol,
                    t_max=t_max)
            else:
                optimizer = GradientDescent(
                    n_outer=n_outer, p_grad_norm=1, verbose=True, tol=tol,
                    t_max=t_max,
                    tol_decrease="geom")
            grad_search(
                algo, criterion, model, optimizer, X, y, alpha0,
                monitor)
        else:
            raise NotImplementedError

    monitor.times = np.array(monitor.times)
    monitor.objs = np.array(monitor.objs)
    monitor.objs_test = 0  # TODO
    monitor.alphas = np.array(monitor.alphas)
    return (dataset_name, method, tol, n_outer, tolerance_decrease,
            monitor.times, monitor.objs, monitor.objs_test,
            monitor.alphas, alpha_max,
            model_name)


print("enter sequential")

with parallel_backend("loky", inner_max_num_threads=1):
    results = Parallel(n_jobs=n_jobs, verbose=100)(
        delayed(parallel_function)(
            dataset_name, method, n_outer=n_outer,
            tolerance_decrease=tolerance_decrease, tol=tol)
        for dataset_name, method, n_outer,
        tolerance_decrease in product(
            dataset_names, methods, n_outers, tolerance_decreases))
    print('OK finished parallel')

df = pd.DataFrame(results)
df.columns = [
    'dataset', 'method', 'tol', 'n_outer', 'tolerance_decrease',
    'times', 'objs', 'objs_test', 'alphas', 'alpha_max', 'model_name']

for dataset_name in dataset_names:
    df[df['dataset'] == dataset_name].to_pickle(
        "results/%s_%s.pkl" % (model_name, dataset_name))
# Out:
# enter sequential
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# Dataset: real-sim
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 0.004388130584600358, tolerance: 8.530272488371793e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 0.006774739822653725, tolerance: 8.531336526118594e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 0.004845185752184178, tolerance: 8.510842697262433e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 0.0045764296551956685, tolerance: 8.534264850368345e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 0.002376016434770478, tolerance: 8.485209868069887e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# Iteration 1/1 ||Value outer criterion: 2.49e-01 ||norm grad 5.99e-02
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    6.3s remaining:    0.0s
# Dataset: real-sim
# Iteration 1/1 ||Value outer criterion: 2.50e-01 ||norm grad 5.70e-02
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:   13.3s remaining:    0.0s
# Dataset: real-sim
# Iteration 1 / 10
# Iteration 2 / 10
# Iteration 3 / 10
# Iteration 4 / 10
# Iteration 5 / 10
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 2.7985671502417375e-08, tolerance: 8.531336526118594e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 5.652911402864724e-08, tolerance: 8.510842697262433e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 4.7874220338028906e-08, tolerance: 8.534264850368345e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 5.8630950677818205e-08, tolerance: 8.485209868069887e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# Iteration 6 / 10
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 3.74909231382059e-07, tolerance: 8.530272488371793e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 2.32681247797073e-07, tolerance: 8.531336526118594e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 1.035521597636535e-07, tolerance: 8.510842697262433e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 7.50149082823226e-07, tolerance: 8.534264850368345e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 1.3195733589155267e-08, tolerance: 8.485209868069887e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# Iteration 7 / 10
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 1.0227641165233559e-06, tolerance: 8.530272488371793e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 7.341629926216342e-08, tolerance: 8.531336526118594e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 1.8618056706748431e-06, tolerance: 8.510842697262433e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 4.6979802308111385e-07, tolerance: 8.534264850368345e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 3.651764032830407e-08, tolerance: 8.485209868069887e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# Iteration 8 / 10
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 6.700926913488781e-07, tolerance: 8.530272488371793e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 2.658119753473631e-08, tolerance: 8.531336526118594e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 8.918654954837013e-08, tolerance: 8.510842697262433e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 8.985026112018346e-09, tolerance: 8.534264850368345e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 4.185073805562656e-08, tolerance: 8.485209868069887e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# Iteration 9 / 10
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 1.8393501364372122e-07, tolerance: 8.530272488371793e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 1.3602564061729328e-06, tolerance: 8.531336526118594e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 5.065049351118955e-07, tolerance: 8.510842697262433e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 4.390217307054245e-08, tolerance: 8.534264850368345e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 1.6649234848772898e-06, tolerance: 8.485209868069887e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# Iteration 10 / 10
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 2.554301971532946e-07, tolerance: 8.530272488371793e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 3.594631187847641e-08, tolerance: 8.531336526118594e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 5.664149093781434e-07, tolerance: 8.510842697262433e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 2.0341815117758122e-07, tolerance: 8.534264850368345e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# /Users/arthurthomas/opt/miniconda3/lib/python3.8/site-packages/celer/homotopy.py:303: ConvergenceWarning: Objective did not converge: duality gap: 1.5191049711205107e-07, tolerance: 8.485209868069887e-09. Increasing `tol` may make the solver faster without affecting the results much.
# Fitting data with very small alpha causes precision issues.
#   sol = celer(
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed: 10.6min remaining:    0.0s
# Dataset: real-sim
#   0%|          | 0/3 [00:00<?, ?trial/s, best loss=?]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [1], in <cell line: 141>()
#     139 print("enter sequential")
#     141 with parallel_backend("loky", inner_max_num_threads=1):
# --> 142     results = Parallel(n_jobs=n_jobs, verbose=100)(
#     143         delayed(parallel_function)(
#     144             dataset_name, method, n_outer=n_outer,
#     145             tolerance_decrease=tolerance_decrease, tol=tol)
#     146         for dataset_name, method, n_outer,
#     147         tolerance_decrease in product(
#     148             dataset_names, methods, n_outers, tolerance_decreases))
#     149     print('OK finished parallel')
#     151 df = pd.DataFrame(results)
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/joblib/parallel.py:1046, in Parallel.__call__(self, iterable)
#    1043 if self.dispatch_one_batch(iterator):
#    1044     self._iterating = self._original_iterator is not None
# -> 1046 while self.dispatch_one_batch(iterator):
#    1047     pass
#    1049 if pre_dispatch == "all" or n_jobs == 1:
#    1050     # The iterable was consumed all at once by the above for loop.
#    1051     # No need to wait for async callbacks to trigger to
#    1052     # consumption.
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/joblib/parallel.py:861, in Parallel.dispatch_one_batch(self, iterator)
#     859     return False
#     860 else:
# --> 861     self._dispatch(tasks)
#     862     return True
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/joblib/parallel.py:779, in Parallel._dispatch(self, batch)
#     777 with self._lock:
#     778     job_idx = len(self._jobs)
# --> 779     job = self._backend.apply_async(batch, callback=cb)
#     780     # A job can complete so quickly than its callback is
#     781     # called before we get here, causing self._jobs to
#     782     # grow. To ensure correct results ordering, .insert is
#     783     # used (rather than .append) in the following line
#     784     self._jobs.insert(job_idx, job)
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py:572, in ImmediateResult.__init__(self, batch)
#     569 def __init__(self, batch):
#     570     # Don't delay the application, to avoid keeping the input
#     571     # arguments in memory
# --> 572     self.results = batch()
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/joblib/parallel.py:262, in BatchedCalls.__call__(self)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/joblib/parallel.py:262, in <listcomp>(.0)
#     258 def __call__(self):
#     259     # Set the default nested backend to self._backend but do not set the
#     260     # change the default number of processes to -1
#     261     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262         return [func(*args, **kwargs)
#     263                 for func, args, kwargs in self.items]
#
# Input In [1], in parallel_function(dataset_name, method, tol, n_outer, tolerance_decrease)
#     103     grid_search(criterion, model, X, y, alpha_min, alpha_max,
#     104         monitor, max_evals=10, tol=tol)
#     105 elif method == 'random' or method == 'bayesian':
# --> 106     hyperopt_wrapper(
#     107         algo, criterion, model, X, y, alpha_min, alpha_max,
#     108         monitor, max_evals=3, tol=tol, method=method, size_space=1,
#     109         t_max=t_max)
#     110 elif method.startswith("implicit_forward"):
#     111     # do gradient descent to find the optimal lambda
#     112     alpha0 = alpha_max / 100
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/sparse_ho/ho.py:123, in hyperopt_wrapper(algo, criterion, model, X, y, alpha_min, alpha_max, monitor, max_evals, tol, random_state, t_max, method, size_space)
#     119     fmin(
#     120         objective, space, algo=algo, max_evals=max_evals,
#     121         timeout=t_max, rstate=rng)
#     122 elif method == "random":
# --> 123     fmin(
#     124         objective, space, algo=rand.suggest, max_evals=max_evals,
#     125         timeout=t_max, rstate=rng)
#     126 return monitor
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~/opt/miniconda3/lib/python3.8/site-packages/hyperopt/fmin.py:279, in FMinIter.run(self, N, block_until_done)
#     273 self.trials.refresh()
#     274 # Based on existing trials and the domain, use `algo` to probe in
#     275 # new hp points. Save the results of those inspections into
#     276 # `new_trials`. This is the core of `run`, all the rest is just
#     277 # processes orchestration
#     278 new_trials = algo(
# --> 279     new_ids, self.domain, trials, self.rstate.integers(2 ** 31 - 1)
#     280 )
#     281 assert len(new_ids) >= len(new_trials)
#     283 if len(new_trials):
#
# AttributeError: 'numpy.random.mtrand.RandomState' object has no attribute 'integers'
